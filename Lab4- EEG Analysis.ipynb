# %% [markdown]
# # Lab 4
#
# Introduction to  EEG Analysis. This notebook is for you to get exposure to EEG signal analysis and artifact removal.
#
# ## EEG Theory
#
# ### Eletroencephalography
#
# The electroencephalogram or EEG is a recording of the biopotentials in the cerebrum of thebrain. These potentials are typical recorded at the surface of the scalp and can vary withrespect to the emotional, mental, and physiological state of a person. The action potentialsand synaptic potentials of an individual neurons are too small to be measured by electrodes.Therefore, an EEG is a measurement of the summation of the electrical signals produce byneurons in a defined area and over a specific amount of time. It is important to note that theseneurons need not synchronized but may be producing signals in an asynchronous manner.EEG signals can be categorizedby the four major frequency ranges or brainwaves in whichthey occur: alpha, beta, delta and theta. The corresponding frequencies, amplitudes, andtypical human functionality of the waves are seen in Table.
#
#
# | Brainwave | Frequency | Amplitude (uV) | Human Function |
# | --------- | --------- | -------------- | -------------- |
# | alpha | 8 - 13 | 2 - 100 | Awake, Quiet, Resting, Eyes Open|
# | beta | 13 - 22 | 5 - 100 | Mental Activity or External Stimulus|
# | delta | 0.4 - 4 | 20 - 100| Sleep |
# | theta | 4 - 8 | 10 | Emotional Stress |
#
#
# A special system of electrode placement called the 10-20 system is used during EEG recordings.The 10 and 20 refer to percent distances of the electrodes from each other with respect to the sizeof the patient’s head. The letters F, T, C, P, and O in the 10 20 system refer to frontal, temporal,central, parietal, and occipital or essential lobes of the brain excluding central. Also, even numbers are located on the right hemisphere and odd numbers on the left hemisphere. The letterz is an indicator of the central line of the head.

# %%
'''You will need to install the following package'''
# !pip3 install fooof
# Out:
# Collecting fooof
#   Using cached fooof-1.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting numpy (from fooof)
#   Downloading numpy-2.2.4-cp310-cp310-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting scipy>=0.19 (from fooof)
#   Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_x86_64.whl.metadata (61 kB)
# Using cached fooof-1.1.0-py3-none-any.whl (133 kB)
# Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_x86_64.whl (25.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.2.4-cp310-cp310-macosx_14_0_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: numpy, scipy, fooof
# Successfully installed fooof-1.1.0 numpy-2.2.4 scipy-1.15.2

# %%
# !pip3 install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: numpy>=1.22.4 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp310-cp310-macosx_10_9_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 2.2 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.2 tzdata-2025.2

# %%
# !pip3 install mne
# Out:
# Collecting mne
#   Downloading mne-1.9.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from mne) (3.1.6)
# Collecting lazy-loader>=0.3 (from mne)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting matplotlib>=3.6 (from mne)
#   Downloading matplotlib-3.10.1-cp310-cp310-macosx_10_12_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from mne) (2.2.4)
# Requirement already satisfied: packaging in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from mne) (24.2)
# Collecting pooch>=1.5 (from mne)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.9 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from mne) (1.15.2)
# Collecting tqdm (from mne)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6->mne)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6->mne)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6->mne)
#   Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6->mne)
#   Downloading kiwisolver-1.4.8-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.2 kB)
# Collecting pillow>=8 (from matplotlib>=3.6->mne)
#   Downloading pillow-11.2.1-cp310-cp310-macosx_10_10_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.6->mne)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from pooch>=1.5->mne) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: six>=1.5 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.1.31)
# Downloading mne-1.9.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 3.8 MB/s eta 0:00:0000:0100:01
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading matplotlib-3.10.1-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.8-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
# Downloading pillow-11.2.1-cp310-cp310-macosx_10_10_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: tqdm, pyparsing, pillow, lazy-loader, kiwisolver, fonttools, cycler, contourpy, pooch, matplotlib, mne
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 lazy-loader-0.4 matplotlib-3.10.1 mne-1.9.0 pillow-11.2.1 pooch-1.8.2 pyparsing-3.2.3 tqdm-4.67.1

# %%
# !pip3 install mne.time_frequency
# Out:
# ERROR: Could not find a version that satisfies the requirement mne.time_frequency (from versions: none)
# ERROR: No matching distribution found for mne.time_frequency

# %% [markdown]
# ## Import the CSV
# We first need to read in the csv file name from your data. Please insert the name of your file in the code below:

# %%
import pandas as pd
import mne 
import os
import scipy
# Opens up another window with your plot
# %matplotlib qt 
# Read in Data
directory = 'Lab_4_Data'
file = 'recording_2023-04-13-08.35.52.csv'
EEGCsv = pd.read_csv(os.path.join(directory, file))
EEGCsv.index = pd.to_datetime(EEGCsv['timestamps'], unit='s')

# Set channel sampling frequency
fs = 250
seconds = EEGCsv.timestamps- EEGCsv.timestamps.iloc[0]

ch_names = [ 'Fz', 'C3', 'Cz', 'C4', 'Pz', 'PO7', 'Oz', 'PO8'] # set EEG channel names
for ch in [ 'Fz', 'C3', 'Cz', 'C4', 'Pz', 'PO7', 'Oz', 'PO8']:
    EEGCsv[ch] = EEGCsv[ch]/100000 # rescale data (uv to volts)
    EEGCsv[ch] = mne.filter.filter_data(EEGCsv[ch].values, 250, 0.1, 100) # apply a highpass filter
    EEGCsv[ch] = mne.baseline.rescale(EEGCsv[ch].values, seconds, (0,10)) # apply baseline rescaling    

display(EEGCsv)
# Out:
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
# Setting up band-pass filter from 0.1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 8251 samples (33.004 s)
#
# Applying baseline correction (mode: mean)
#                                  timestamps        Fz        C3        Cz  \
# timestamps
# 2023-04-13 08:36:18.510309219  1.681375e+09  0.006442 -0.016188 -0.000180
# 2023-04-13 08:36:18.522958516  1.681375e+09 -0.003779 -0.016570 -0.001210
# 2023-04-13 08:36:18.525979280  1.681375e+09  0.005377 -0.015478 -0.000769
# 2023-04-13 08:36:18.526016712  1.681375e+09  0.015582 -0.013947  0.000110
# 2023-04-13 08:36:18.534096718  1.681375e+09  0.016672 -0.012902  0.000505
# ...                                     ...       ...       ...       ...
# 2023-04-13 08:38:18.770231247  1.681375e+09 -0.006257 -0.035769 -0.001121
# 2023-04-13 08:38:18.770256281  1.681375e+09 -0.008522 -0.051922 -0.001560
# 2023-04-13 08:38:18.777066708  1.681375e+09  0.003228 -0.038180 -0.000834
# 2023-04-13 08:38:18.779548883  1.681375e+09  0.009353 -0.020605 -0.000230
# 2023-04-13 08:38:18.783261776  1.681375e+09  0.006442 -0.016188 -0.000180
#
#                                      C4        Pz       PO7        Oz  \
# timestamps
# 2023-04-13 08:36:18.510309219  0.029688 -0.000153 -0.000151 -0.000175
# 2023-04-13 08:36:18.522958516  0.024400 -0.001180 -0.001181 -0.001201
# 2023-04-13 08:36:18.525979280  0.028851 -0.000736 -0.000739 -0.000761
# 2023-04-13 08:36:18.526016712  0.034058  0.000146  0.000143  0.000121
# 2023-04-13 08:36:18.534096718  0.035322  0.000539  0.000535  0.000515
# ...                                 ...       ...       ...       ...
# 2023-04-13 08:38:18.770231247  0.023300 -0.001097 -0.017592 -0.001118
# 2023-04-13 08:38:18.770256281  0.022148 -0.001523 -0.033681 -0.001557
# 2023-04-13 08:38:18.777066708  0.027536 -0.000797 -0.023971 -0.000831
# 2023-04-13 08:38:18.779548883  0.030612 -0.000225 -0.007678 -0.000228
# 2023-04-13 08:38:18.783261776  0.029688 -0.000153 -0.000151 -0.000175
#
#                                     PO8  stim
# timestamps
# 2023-04-13 08:36:18.510309219  0.011465   0.0
# 2023-04-13 08:36:18.522958516  0.003785   0.0
# 2023-04-13 08:36:18.525979280  0.005219   0.0
# 2023-04-13 08:36:18.526016712  0.010926   0.0
# 2023-04-13 08:36:18.534096718  0.014763   0.0
# ...                                 ...   ...
# 2023-04-13 08:38:18.770231247  0.005050   0.0
# 2023-04-13 08:38:18.770256281  0.000640   0.0
# 2023-04-13 08:38:18.777066708  0.004980   0.0
# 2023-04-13 08:38:18.779548883  0.009996   0.0
# 2023-04-13 08:38:18.783261776  0.011465   0.0
#
# [30119 rows x 10 columns]

# %% [markdown]
# ## EEG Signals
# The above code prints out a table containing your collected data. One thing to note is the column names and what they correspond to. We have time, electrode position values, and Stim (0 or 1). For now, lets focus on the electrode positions.
#
# The data was collected using the standard 10-20 placement. The code below shows you these positions.

# %%
mon = mne.channels.make_standard_montage('standard_1020')
mon.plot(kind='topomap', show_names=True)# 2d Plot
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.

# %%
# The window that this opens is interactable, so you can rotate around to get a better idea where each electrode is.
mon.plot(kind='3d', show_names=True)# 3d Plot
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.

# %% [markdown]
# We now need to plot signals from our dataset. Unfortunately, some of the electrode positions are incorrectly named and need to be renamed. Our analysis uses the MNE toolbox. Feel free to look at the MNE documentation online.

# %% [markdown]
# # Plot the raw data

# %%
# Create MNE Info to apply to csv data
info = mne.create_info(ch_names, fs, ch_types='eeg')

df_mne = EEGCsv[ch_names]

# Create the Raw Object for MNE
raw = mne.io.RawArray(df_mne.values.transpose(), info)


# Plot the data
raw.plot(n_channels=8)

'''You can scale the graphs using +/-'''
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=30119
#     Range : 0 ... 30118 =      0.000 ...   120.472 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# 'You can scale the graphs using +/-'

# %% [markdown]
# ## Plot the PSD

# %%
raw.plot_psd(area_mode='range', tmax=10.0, show=False, average=True)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %% [markdown]
# ## Notch Filter
#
# You should see a spike in the PSD ~60. The code below will apply a notch filter at 60 Hz.

# %%
import scipy
import scipy.fftpack
import matplotlib.pyplot as plt
import numpy as np
# Run the following to create a notch filter at 60 hz and view the resulting PSD
raw.notch_filter(np.arange(60, 128, 60))
raw.plot_psd(area_mode='range', tmax=10.0, show=False, average=True)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 1651 samples (6.604 s)
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 8.192 (s)
# Plotting power spectral density (dB=True).
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
def check_nans(data, nan_policy='zero'):
    """Check an array for nan values, and replace, based on policy."""

    # Find where there are nan values in the data
    nan_inds = np.where(np.isnan(data))

    # Apply desired nan policy to data
    if nan_policy == 'zero':
        data[nan_inds] = 0
    elif nan_policy == 'mean':
        data[nan_inds] = np.nanmean(data)
    else:
        raise ValueError('Nan policy not understood.')

    return data

# %%
from mne.viz import plot_topomap
from mne.time_frequency import psd_welch
from mne.time_frequency import psd_array_welch

# FOOOF imports
from fooof import FOOOFGroup
from fooof.bands import Bands
from fooof.analysis import get_band_peak_fg
from fooof.plts.spectra import plot_spectrum

from matplotlib import cm, colors, colorbar

'''Set the 10-20 montage for our data'''
raw.set_montage(mon)

'''Apply the PSD Welch algorithm to get the Power Spectral Density'''
spectra, freqs = psd_welch(raw, fmin=1, fmax=40, tmin=0, tmax=250,
                           n_overlap=150, n_fft=250)

# spectra, freqs = psd_array_welch(raw, fmin=1, fmax=40, 
#                            n_overlap=150, n_fft=250, sfreq=250)

# Initialize a FOOOFGroup object, with desired settings
fg = FOOOFGroup(peak_width_limits=[1, 6], min_peak_height=0.15,
                peak_threshold=2., max_n_peaks=6, verbose=False)

# Define the frequency range to fit
freq_range = [1, 30]

# Fit the power spectrum model across all channels
fg.fit(freqs, spectra, freq_range)

# Define frequency bands of interest
bands = Bands({'theta': [3, 7],
               'alpha': [7, 14],
               'beta': [15, 30]})

# Extract alpha peaks
alphas = get_band_peak_fg(fg, bands.alpha)

# Extract the power values from the detected peaks
alpha_pw = alphas[:, 1]

# We need to remove nans for the plot to show
alpha_pw = check_nans(alpha_pw) 

# Plot the topography of alpha power
plot_topomap(alpha_pw, raw.info, cmap=cm.viridis, contours=0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 from mne.viz import plot_topomap
# ----> 2 from mne.time_frequency import psd_welch
#       3 from mne.time_frequency import psd_array_welch
#       5 # FOOOF imports
#
# ImportError: cannot import name 'psd_welch' from 'mne.time_frequency' (/Users/thanialthani/opt/anaconda3/envs/eeglab2/lib/python3.10/site-packages/mne/time_frequency/__init__.py)

# %%
# Define frequency bands of interest
bands = Bands({'theta': [3, 7],
               'alpha': [7, 14],
               'beta': [15, 30]})

fig, axes = plt.subplots(1, 3, figsize=(15, 6))
for ind, (label, band_def) in enumerate(bands):

    # Get the power values across channels for the current band
    band_power = check_nans(get_band_peak_fg(fg, band_def)[:, 1])

    # Extracted and plot the power spectrum model with the most band power
    fg.get_fooof(np.argmax(band_power)).plot(ax=axes[ind], add_legend=False)

    # Set some plot aesthetics & plot title
    axes[ind].yaxis.set_ticklabels([])
    axes[ind].set_title('Largest ' + label + ' peak', {'fontsize' : 16})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Define frequency bands of interest
# ----> 2 bands = Bands({'theta': [3, 7],
#       3                'alpha': [7, 14],
#       4                'beta': [15, 30]})
#       6 fig, axes = plt.subplots(1, 3, figsize=(15, 6))
#       7 for ind, (label, band_def) in enumerate(bands):
#       8
#       9     # Get the power values across channels for the current band
#
# NameError: name 'Bands' is not defined

# %% [markdown]
# ## Event Related Potentials
#
# Now that we have an idea of how to extract some meaningful information from EEG signals, we need to do some analysis specifically with our dataset.
#
# Cats and dogs flashed on the screen. The participant is looking for a specific stimulus, hence the 'stim' column. These stimuli produce what is called a P300 Event Related Potential. We are going to analyze these potentials between the target and non target stimuli.

# %%
# We are going to go back to the original dataset and use the Pandas Groupby method to figure out when the target events occur
EEGCsv.groupby('stim').get_group(1)
# Out:
#                                  timestamps        Fz        C3        Cz  \
# timestamps
# 2023-04-13 08:36:18.937731266  1.681375e+09  0.000766  0.052716 -0.000679
# 2023-04-13 08:36:19.722768784  1.681375e+09  0.006324  0.179193  0.000123
# 2023-04-13 08:36:21.306635141  1.681375e+09  0.004886  0.048712  0.000789
# 2023-04-13 08:36:22.169672489  1.681375e+09 -0.002863  0.037679  0.000359
# 2023-04-13 08:36:23.077771902  1.681375e+09 -0.011848 -0.008847 -0.000630
# ...                                     ...       ...       ...       ...
# 2023-04-13 08:38:08.540261269  1.681375e+09  0.002735 -0.012893 -0.000251
# 2023-04-13 08:38:13.595766783  1.681375e+09  0.000314 -0.034769 -0.000932
# 2023-04-13 08:38:15.203383207  1.681375e+09  0.010003 -0.003764  0.000181
# 2023-04-13 08:38:16.038323641  1.681375e+09  0.011409 -0.013001  0.000052
# 2023-04-13 08:38:16.870793104  1.681375e+09 -0.008577 -0.039628 -0.001302
#
#                                      C4        Pz       PO7        Oz  \
# timestamps
# 2023-04-13 08:36:18.937731266  0.013825 -0.000648 -0.000653 -0.000677
# 2023-04-13 08:36:19.722768784 -0.000667  0.000109  0.000114  0.000129
# 2023-04-13 08:36:21.306635141 -0.012287  0.000755  0.000752  0.000788
# 2023-04-13 08:36:22.169672489 -0.014170  0.000335  0.000336  0.000354
# 2023-04-13 08:36:23.077771902 -0.015112 -0.000640 -0.000640 -0.000634
# ...                                 ...       ...       ...       ...
# 2023-04-13 08:38:08.540261269  0.027766 -0.000227  0.005310 -0.000240
# 2023-04-13 08:38:13.595766783  0.026637 -0.000894 -0.018248 -0.000929
# 2023-04-13 08:38:15.203383207  0.031744  0.000201  0.010428  0.000187
# 2023-04-13 08:38:16.038323641  0.031643  0.000067 -0.002587  0.000056
# 2023-04-13 08:38:16.870793104  0.022251 -0.001263 -0.023390 -0.001290
#
#                                     PO8  stim
# timestamps
# 2023-04-13 08:36:18.937731266 -0.000614   1.0
# 2023-04-13 08:36:19.722768784 -0.001938   1.0
# 2023-04-13 08:36:21.306635141 -0.000086   1.0
# 2023-04-13 08:36:22.169672489 -0.002367   1.0
# 2023-04-13 08:36:23.077771902 -0.008607   1.0
# ...                                 ...   ...
# 2023-04-13 08:38:08.540261269  0.012306   1.0
# 2023-04-13 08:38:13.595766783  0.005938   1.0
# 2023-04-13 08:38:15.203383207  0.014681   1.0
# 2023-04-13 08:38:16.038323641  0.011695   1.0
# 2023-04-13 08:38:16.870793104  0.003167   1.0
#
# [61 rows x 10 columns]

# %%
import datetime as dt
# We can now compare an ERP between a target and non-target event.
# We need to slice our dataframe to get the P300 timeframe from these events.
# P300 events occur when a positive deflection occurs approx 300 msec after a triggering event (stimulus)
# Lets see if we can find this peak visually

# We first find a target time by using the .iloc method
TargetTime = EEGCsv.groupby('stim').get_group(1).index[0]

# Then we can index the TimeFrame for the P300
StartTime = TargetTime - dt.timedelta(200*0.001) # Starting at -200 msec
EndTime   = TargetTime + dt.timedelta(500*0.001) # Ending at 500 msec

ERPdf = EEGCsv[(EEGCsv.index > StartTime) & (EEGCsv.index < EndTime)]

# Lets look at what the raw data looks like for 1 ERP
display(ERPdf)

# This code will be useful for the lab questions when computing the PSD of the ERPs. The next code sections are better for plotting
# Out:
#                                  timestamps        Fz        C3        Cz  \
# timestamps
# 2023-04-13 08:36:18.510309219  1.681375e+09  0.006442 -0.016188 -0.000180
# 2023-04-13 08:36:18.522958516  1.681375e+09 -0.003779 -0.016570 -0.001210
# 2023-04-13 08:36:18.525979280  1.681375e+09  0.005377 -0.015478 -0.000769
# 2023-04-13 08:36:18.526016712  1.681375e+09  0.015582 -0.013947  0.000110
# 2023-04-13 08:36:18.534096718  1.681375e+09  0.016672 -0.012902  0.000505
# ...                                     ...       ...       ...       ...
# 2023-04-13 08:38:18.770231247  1.681375e+09 -0.006257 -0.035769 -0.001121
# 2023-04-13 08:38:18.770256281  1.681375e+09 -0.008522 -0.051922 -0.001560
# 2023-04-13 08:38:18.777066708  1.681375e+09  0.003228 -0.038180 -0.000834
# 2023-04-13 08:38:18.779548883  1.681375e+09  0.009353 -0.020605 -0.000230
# 2023-04-13 08:38:18.783261776  1.681375e+09  0.006442 -0.016188 -0.000180
#
#                                      C4        Pz       PO7        Oz  \
# timestamps
# 2023-04-13 08:36:18.510309219  0.029688 -0.000153 -0.000151 -0.000175
# 2023-04-13 08:36:18.522958516  0.024400 -0.001180 -0.001181 -0.001201
# 2023-04-13 08:36:18.525979280  0.028851 -0.000736 -0.000739 -0.000761
# 2023-04-13 08:36:18.526016712  0.034058  0.000146  0.000143  0.000121
# 2023-04-13 08:36:18.534096718  0.035322  0.000539  0.000535  0.000515
# ...                                 ...       ...       ...       ...
# 2023-04-13 08:38:18.770231247  0.023300 -0.001097 -0.017592 -0.001118
# 2023-04-13 08:38:18.770256281  0.022148 -0.001523 -0.033681 -0.001557
# 2023-04-13 08:38:18.777066708  0.027536 -0.000797 -0.023971 -0.000831
# 2023-04-13 08:38:18.779548883  0.030612 -0.000225 -0.007678 -0.000228
# 2023-04-13 08:38:18.783261776  0.029688 -0.000153 -0.000151 -0.000175
#
#                                     PO8  stim
# timestamps
# 2023-04-13 08:36:18.510309219  0.011465   0.0
# 2023-04-13 08:36:18.522958516  0.003785   0.0
# 2023-04-13 08:36:18.525979280  0.005219   0.0
# 2023-04-13 08:36:18.526016712  0.010926   0.0
# 2023-04-13 08:36:18.534096718  0.014763   0.0
# ...                                 ...   ...
# 2023-04-13 08:38:18.770231247  0.005050   0.0
# 2023-04-13 08:38:18.770256281  0.000640   0.0
# 2023-04-13 08:38:18.777066708  0.004980   0.0
# 2023-04-13 08:38:18.779548883  0.009996   0.0
# 2023-04-13 08:38:18.783261776  0.011465   0.0
#
# [30119 rows x 10 columns]

# %% [markdown]
# ### MNE Library and ERPs
# We first need to drop columns from our raw data that are not EEG based. Then we can scale and create a raw MNE array for easy plotting.
#
# The next step creates Event Info from our Event column in the original array. We can then use MNE functionality to plot the ERPs between target and non-target events.

# %%
# Create MNE Info to apply to csv data
info = mne.create_info(ch_names, fs, ch_types='eeg')
info['chs'][-1]['kind']



# Create Raw Array
raw = mne.io.RawArray(df_mne.transpose(), info)


# Create Event info and add to raw array
info = mne.create_info(['STI 0'], raw.info['sfreq'], ['stim'])
temp = EEGCsv['stim'].values
temp = np.reshape(temp, (1, -1))
stim_raw = mne.io.RawArray(temp, info)
raw.add_channels([stim_raw], force_update_info=True)

# Get events object for easy access
events = mne.find_events(raw, stim_channel='STI 0', verbose=True)

display(events)

# Plot the data
raw.plot(events = events, n_channels=8)

# Note the vertical lines indicating events
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=30119
#     Range : 0 ... 30118 =      0.000 ...   120.472 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1, n_times=30119
#     Range : 0 ... 30118 =      0.000 ...   120.472 secs
# Ready.
# 146 events found on stim channel STI 0
# Event IDs: [1 2]
# array([[  107,     0,     1],
#        [  303,     0,     1],
#        [  486,     0,     2],
#        [  690,     0,     1],
#        [  916,     0,     1],
#        [ 1143,     0,     1],
#        [ 1351,     0,     1],
#        [ 1549,     0,     2],
#        [ 1751,     0,     2],
#        [ 1967,     0,     2],
#        [ 2160,     0,     2],
#        [ 2353,     0,     2],
#        [ 2568,     0,     2],
#        [ 2763,     0,     1],
#        [ 2987,     0,     2],
#        [ 3174,     0,     2],
#        [ 3387,     0,     2],
#        [ 3623,     0,     2],
#        [ 3816,     0,     1],
#        [ 4000,     0,     1],
#        [ 4229,     0,     2],
#        [ 4434,     0,     1],
#        [ 4634,     0,     2],
#        [ 4814,     0,     1],
#        [ 5028,     0,     1],
#        [ 5265,     0,     1],
#        [ 5456,     0,     2],
#        [ 5671,     0,     2],
#        [ 5904,     0,     2],
#        [ 6104,     0,     2],
#        [ 6294,     0,     2],
#        [ 6535,     0,     2],
#        [ 6727,     0,     2],
#        [ 6905,     0,     2],
#        [ 7123,     0,     2],
#        [ 7302,     0,     2],
#        [ 7495,     0,     1],
#        [ 7678,     0,     1],
#        [ 7860,     0,     2],
#        [ 8050,     0,     2],
#        [ 8287,     0,     2],
#        [ 8481,     0,     2],
#        [ 8690,     0,     2],
#        [ 8881,     0,     2],
#        [ 9112,     0,     1],
#        [ 9301,     0,     1],
#        [ 9481,     0,     2],
#        [ 9709,     0,     2],
#        [ 9943,     0,     1],
#        [10162,     0,     1],
#        [10356,     0,     1],
#        [10542,     0,     2],
#        [10768,     0,     2],
#        [10981,     0,     2],
#        [11180,     0,     2],
#        [11364,     0,     1],
#        [11605,     0,     2],
#        [11824,     0,     1],
#        [12036,     0,     1],
#        [12242,     0,     1],
#        [12450,     0,     1],
#        [12661,     0,     1],
#        [12894,     0,     2],
#        [13061,     0,     2],
#        [13296,     0,     2],
#        [13508,     0,     2],
#        [13751,     0,     1],
#        [13965,     0,     2],
#        [14186,     0,     1],
#        [14363,     0,     1],
#        [14570,     0,     2],
#        [14764,     0,     2],
#        [14932,     0,     2],
#        [15181,     0,     1],
#        [15402,     0,     1],
#        [15600,     0,     2],
#        [15822,     0,     1],
#        [16033,     0,     1],
#        [16241,     0,     2],
#        [16427,     0,     2],
#        [16666,     0,     1],
#        [16859,     0,     1],
#        [17070,     0,     2],
#        [17270,     0,     2],
#        [17489,     0,     1],
#        [17680,     0,     2],
#        [17849,     0,     2],
#        [18068,     0,     2],
#        [18267,     0,     1],
#        [18466,     0,     2],
#        [18670,     0,     1],
#        [18898,     0,     2],
#        [19078,     0,     2],
#        [19276,     0,     1],
#        [19494,     0,     1],
#        [19686,     0,     1],
#        [19877,     0,     2],
#        [20083,     0,     2],
#        [20306,     0,     1],
#        [20513,     0,     2],
#        [20728,     0,     1],
#        [20922,     0,     1],
#        [21111,     0,     2],
#        [21302,     0,     1],
#        [21532,     0,     1],
#        [21711,     0,     2],
#        [21908,     0,     2],
#        [22117,     0,     1],
#        [22327,     0,     1],
#        [22548,     0,     2],
#        [22745,     0,     1],
#        [22959,     0,     2],
#        [23161,     0,     2],
#        [23400,     0,     2],
#        [23606,     0,     1],
#        [23839,     0,     2],
#        [24053,     0,     2],
#        [24247,     0,     2],
#        [24433,     0,     1],
#        [24627,     0,     1],
#        [24847,     0,     2],
#        [25061,     0,     2],
#        [25246,     0,     1],
#        [25442,     0,     2],
#        [25626,     0,     2],
#        [25853,     0,     2],
#        [26062,     0,     2],
#        [26271,     0,     1],
#        [26469,     0,     2],
#        [26692,     0,     1],
#        [26912,     0,     2],
#        [27104,     0,     1],
#        [27352,     0,     2],
#        [27551,     0,     1],
#        [27753,     0,     2],
#        [27993,     0,     2],
#        [28197,     0,     2],
#        [28386,     0,     2],
#        [28587,     0,     2],
#        [28819,     0,     1],
#        [29032,     0,     2],
#        [29212,     0,     1],
#        [29411,     0,     1],
#        [29639,     0,     1],
#        [29823,     0,     2],
#        [30038,     0,     2]])
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# Set epoch length to -0.2 seconds before stimulus and 0.5 after stimulus
tmin, tmax = -0.2, 0.5

# Set the epoch parameters based on the events in the raw data
epochs_params = dict(events=events, event_id=1, tmin=tmin, tmax=tmax)

# Now we parse our data based on the target events and take the average of all channels
epochs = mne.Epochs(raw, **epochs_params).average()
# Set montage to 10-20
epochs.set_montage(mon)
# Plot EEG data and a topomap
display(epochs.plot())
epochs.plot_topomap()
# Out:
# Not setting metadata
# 61 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# <MNEFigure size 600x220 with 5 Axes>
# <MNEFigure size 600x220 with 5 Axes>

# %% [markdown]
# ## We can do this for our dog pictures as well

# %%
# Set epoch length to -0.2 seconds before stimulus and 0.5 after stimulus
tmin, tmax = -0.2, 0.5


# Set the epoch parameters based on the events in the raw data
epochs_params = dict(events=events, event_id=2, tmin=tmin, tmax=tmax)

# Now we parse our data based on the target events and take the average of all channels
epochs = mne.Epochs(raw, **epochs_params).average()
# Set montage to 10-20
epochs.set_montage(mon)
# Plot EEG data and a topomap
display(epochs.plot())
epochs.plot_topomap()
# Out:
# Not setting metadata
# 85 matching events found
# Setting baseline interval to [-0.2, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# <MNEFigure size 600x220 with 5 Axes>
# <MNEFigure size 600x220 with 5 Axes>

# %% [markdown]
# We now have two plots for target and non-target events. Note the difference between the two graphs.
